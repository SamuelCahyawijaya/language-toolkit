# %%
import argparse
import string
import sys
import os
import json
import time
import pandas as pd
import requests
from tqdm import tqdm
import zipfile
from IPython.display import display, HTML
from panlex import load_panlex_resources, extract_monolingual_lexicon, extract_bilingual_lexicon

# %%
# %%time
# Test loading resource
print('loading panlex resources...')
stime = time.time()

panlex_dir = 'panlex-20230501-csv'
langvar_df, expr_df, deno_df = load_panlex_resources(panlex_dir)

print(f'finished loading panlex resources in {time.time() - stime:.2f}s')

# Test extract monolingual
print('extracting monolingual lexicon (ind)...')
stime = time.time()

monolingual_lexicon = extract_monolingual_lexicon('ind', langvar_df, expr_df)
display(monolingual_lexicon.head(10))

print(f'finished extracting monolingual lexicon (ind) in {time.time() - stime:.2f}s')

# Test extract bilingual
print('extracting bilingual lexicon (ind-eng)...')
stime = time.time()

bilingual_lexicon = extract_bilingual_lexicon('ind', 'bug', langvar_df, expr_df, deno_df)
display(bilingual_lexicon.head())

print(f'finished extracting bilingual lexicon (ind-end) in {time.time() - stime:.2f}s')
# Out:
# loading panlex resources...
# finished loading panlex resources in 50.70s
# extracting monolingual lexicon (ind)...
#             ind
# 0  menangkalkan
# 1     menyetrum
# 2     radiofoto
# 3      krakatoa
# 4         jiwei
# 5        kanker
# 6        neraca
# 7       dijamin
# 8      pantalon
# 9         focal
# finished extracting monolingual lexicon (ind) in 18.61s
# extracting bilingual lexicon (ind-eng)...
#             ind      bug
# 0  Bahasa Bugis  ᨅᨔ ᨕᨘᨁᨗ
# 1  bahasa bugis  ᨅᨔ ᨕᨘᨁᨗ
# 2      mengkudu       ᨅᨍ
# 3        Jepang      ᨍᨛᨄ
# 4         Korea    ᨀᨚᨑᨗᨕ
# finished extracting bilingual lexicon (ind-end) in 31.07s
# CPU times: user 1min 34s, sys: 6.06 s, total: 1min 40s
# Wall time: 1min 40s

# %%
bilingual_lexicon = extract_bilingual_lexicon('eng', 'cni', langvar_df, expr_df, deno_df)
display(bilingual_lexicon.head())
# Out:
#    eng     cni
# 0    I  nainti
# 1    I    naro
# 2    I  narori
# 3  you   awiro
# 4  one   aparo

# %%
# aym: Jupax sanwa: Mamita, utankastwa || Utar purinxtwa sasaw mamaparux sanxa
# cni: Iriori ikantiro: Ina, nosaiki pankotsiki. || Ikantiro iriniro yaretaja pankotsiki.

# %%
bilingual_lexicon
# Out:
#        eng              cni
# 0        I           nainti
# 1        I             naro
# 2        I           narori
# 3      you            awiro
# 4      one            aparo
# 5      two            apite
# 6   person        amatsenka
# 7     fish             Sima
# 8     fish          parenti
# 9      dog          otsitsi
# 10   louse            netsi
# 11   louse          xenitsi
# 12    tree          intSato
# 13    leaf              oSi
# 14    skin        nomeshina
# 15   blood   irajaSetatsiri
# 16    bone           itonki
# 17    horn           itseki
# 18     ear      kempitantsi
# 19     eye              oki
# 20    nose          noirina
# 21   tooth             nayi
# 22  tongue           nonene
# 23    knee       yeritontsi
# 24    hand             nako
# 25  breast         tsomitsi
# 26   liver         nanatare
# 27   drink           ninero
# 28   drink          nowikea
# 29     see             inei
# 30    hear       nokemakero
# 31    hear         nokemero
# 32    hear      nokempitaka
# 33    come         nopokake
# 34    come        noponeaka
# 35     sun  katsirincaiteri
# 36     sun       poreatsiri
# 37    star         impokiro
# 38   water             nixa
# 39   stone             mapi
# 40    fire           pamari
# 41    path            aotsi
# 42    path           awotsi
# 43    full             xaka
# 44     new         iroakera
# 45    name          noaxiro
# 46    name         nowaxiro
# 47   black          kisaari
# 48   black        cheenkari
# 49     dog          otsitzi
# 50     one           apaani
# 51     red       kityonkari
# 52   three             mawa
# 53     two            apite
# 54   white        kitamaari
# 55     one           apaani
# 56     two            apiti
# 57   three             mava

# %%
bilingual_lexicon.loc[bilingual_lexicon['cni'] == 'ina',:]
# Out:
# Empty DataFrame
# Columns: [eng, cni]
# Index: []

# %%
x = 'Iriori ikantiro Ina nosaiki pankotsiki Ikantiro iriniro yaretaja pankotsiki'.lower()
for token in x.split(' '):
    print(token, bilingual_lexicon.loc[bilingual_lexicon['cni'] == token,:].values)
# Out:
# iriori []
# ikantiro []
# ina []
# nosaiki []
# pankotsiki []
# ikantiro []
# iriniro []
# yaretaja []
# pankotsiki []

# %%
bilingual_lexicon.set_index('spa').head(50).to_dict()
# Out:
# {'aym': {'seis': 'suxta',
#   'agua': 'uma',
#   'tierra': 'uraḳi',
#   'suelo': 'uraḳi',
#   'polvo': 'laḳˀa',
#   'lodo': 'ɲiḳˀi',
#   'arena': 'čˀalʸa',
#   'loma': 'ḳulʸu',
#   'montaña': 'ḳulʸu',
#   'campo': 'pampa',
#   'llanura': 'pampa',
#   'pampa': 'pampa',
#   'valle': 'ḳʰirwa',
#   'isla': 'isla',
#   'costa': 'ḳuta laka',
#   'playa': 'ḳuta laka',
#   'ribera': 'ḳuta laka',
#   'cueva': 'tixi',
#   'mar': 'lamara',
#   'espuma': 'xupʰuḳu',
#   'océano': 'mama-ḳuta',
#   'lago': 'ḳuta',
#   'laguna': 'ḳuta-ɲa',
#   'ola': 'uxi',
#   'arroyo': 'xawira',
#   'corriente': 'xawira',
#   'río': 'xawira',
#   'manantial': 'pʰučˀu',
#   'pozo': 'pʰučˀu',
#   'pantano': 'ḳʰuči',
#   'cascada': 'pʰaxča',
#   'selva': 'čˀumi',
#   'árbol': 'ali',
#   'madera': 'kˀulʸu',
#   'piedra': 'ḳarḳa',
#   'roca': 'ḳarḳa',
#   'cielo': 'laḳampu',
#   'sol': 'wilʸka',
#   'luna': 'pʰaxsi',
#   'estrella': 'wara-wara',
#   'relámpago': 'ḳˀixu-ḳˀixu',
#   'rayo': 'lʸixu-lʸixu',
#   'tempestad': 'wayra'}}

# %%
langvar_df.loc[langvar_df['lang_code'] == 'cni', :]
# Out:
#         id lang_code  var_code mutable  name_expr  script_expr   meaning  \
# 4788  4547       cni         0       t   18586488     18147719  35680514
#
#       region_expr  uid_expr   grp
# 4788     26528845  18586487  4547

# %% [markdown]
# ### In-Context Alignment

# %%
panlex_dir = 'panlex-20230501-csv'
langvar_df, expr_df, deno_df = load_panlex_resources(panlex_dir)

# %%
languages = [
    'amh', 'hau', 'ibo', 'lug', 'pcm', 'sna', 'swc', 'swh', 'xho', 'yor',
    'aym', 'bzd', 'cni', 'grn', 'hch', 'nah', 'oto', 'quy', 'shp', 'tar', 
    'bbc', 'sun', 'jav', 'mad', 'mak', 'min',
    "ara", "fra", "deu", "hin", "ita", "por", "spa"
]

# %%
for lang in languages:
    try:
        print(lang)
        if not os.path.exists(f'lexicons/eng-{lang}_lexicon.csv'):
            bilexicon_df = extract_bilingual_lexicon('eng', lang, langvar_df, expr_df, deno_df) 
            bilexicon_df.to_csv(f'lexicons/eng-{lang}_lexicon.csv', index=False)
    except:
        print('ERROR')
        pass
# Out:
# amh
# hau
# ibo
# lug
# pcm
# sna
# swc
# swh
# xho
# yor
# aym
# bzd
# cni
# grn
# hch
# nah
# oto
# quy
# shp
# tar
# bbc
# sun
# jav
# mad
# mak
# min
# ara
# fra
# deu
# hin
# ita
# por
# spa

# %%
bdfs = {}
for lang in languages:
    try:
        bdfs[lang] = pd.read_csv(f'lexicons/eng-{lang}_lexicon.csv')
    except:
        print('ERROR')
        pass

# %%
af_labels = ['business', 'entertainment', 'health', 'politics', 'religion', 'sports', 'technology']
af_langs = ['amh', 'hau', 'ibo', 'lug', 'pcm', 'sna', 'swc', 'swh', 'xho', 'yor']

sa_labels = ['entailment', 'neutral', 'contradiction']
sa_langs = ['aym', 'bzd', 'cni', 'grn', 'hch', 'nah', 'oto', 'quy', 'shp', 'tar']

id_labels = ['negative', 'neutral', 'positive']
id_langs = ['bbc', 'sun', 'jav', 'mad', 'mak', 'min']

tsm_labels = ['negative', 'neutral', 'positive']
tsm_langs = ['ara', 'fra', 'deu', 'hin', 'ita', 'por', 'spa']

# %%
for lang in af_langs:
    for label in af_labels:
        bdf = bdfs[lang]
        print(bdf.loc[bdf['eng'] == label, lang].values, end='\t')
    print()
# Out:
# []	[]	['ትምህርተ፡ጤና']	['ፖለቲካ']	['ሃይማኖት' 'ሃይማኖት']	[]	['ቴክኖዎሎጂ']
# ['hidimā' 'sabga' 'shagali' 'shaʼani' 'tagala']	[]	['lafiya']	['siyasa']	['àddīnī̀' 'àdíinìi' 'addini' 'addini']	[]	[]
# []	[]	['ezi ndụ̀' 'àrụ ikē' 'ezi ndụ̀']	[]	[]	[]	['nka na uzu']
# ['kusubula' 'okusubula' 'okusubula']	[]	['bulamu' 'kuwangula' 'obulamu' 'okuwangula']	['byʼobufuzi' 'ebyʼobufuzi']	[]	[]	['tekinologia' 'tekinologia' 'tekinologia']
# []	[]	[]	[]	[]	[]	[]
# []	['mutambo']	['hutano']	[]	[]	[]	[]
# []	[]	[]	[]	[]	[]	[]
# ['biashara' 'jambo' 'kitu' 'amali' 'bia' 'biashara' 'duka' 'hoja' 'kazi'
#  'kisa' 'maishilio' 'shughuli' 'tarafa' 'tarafu' 'tatizo' 'tume'
#  'ubiashara' 'amali' 'bia' 'biashara' 'duka' 'hoja' 'kazi' 'kisa'
#  'maishilio' 'tatizo' 'shughuli' 'tarafa' 'tarafu' 'tume' 'ubiashara'
#  'jambo' 'amali' 'amali' 'bia' 'biashara' 'biashara' 'hoja' 'hoja' 'kazi'
#  'maishilio' 'shughuli' 'shughuli' 'tarafa' 'tarafa' 'tarafu' 'tarafu'
#  'tume' 'ubiashara' 'jambo' 'amara' 'shughuli' 'amali' 'biashara'
#  'biashara' 'biashara' 'biashara' 'biashara' 'biashara' 'biashara'
#  'biashara' 'biashara' 'kazi' 'kazi' 'kazi' 'kazi' 'kazi' 'kazi' 'kazi'
#  'kazi' 'kampuni' 'biashara' 'shughuli']	['burudani' 'changamko' 'kichekesho' 'mandari' 'mchezo' 'raha' 'tafrija'
#  'tamasha' 'uhondo' 'vitumbuizo' 'changamko' 'kichekesho' 'mandari'
#  'mchezo' 'raha' 'tafrija' 'tamasha' 'uhondo' 'vitumbuizo' 'burudani'
#  'mandari' 'raha' 'raha' 'tafrija' 'tafrija' 'tafriji' 'tafriji' 'tamasha'
#  'tamasha' 'uhondo' 'vitumbuizo' 'uhondo' 'uhondo' 'burudani' 'burudani'
#  'burudani' 'starehe' 'mafurahisho' 'burudani']	['afya' 'afya' 'afya' 'afya' 'afya' 'afya' 'afya' 'afia' 'afya' 'afya'
#  'rai' 'salama' 'uzima' 'afia' 'afya' 'rai' 'salama' 'uzima' 'afya' 'afya'
#  'afya' 'afia' 'afia' 'afya' 'afya' 'salaam' 'salaam' 'salama' 'uzima'
#  'afya' 'unono' 'afya' 'salama' 'afya' 'afya' 'afya' 'afya' 'afya' 'afya']	['siasa' 'siasa' 'siasa' 'siasa' 'siasa' 'siasa' 'siasa' 'siasa']	['dini' 'dini' 'dini' 'dini' 'dini' 'dini' 'dini' 'madhehebu' 'dini'
#  'dini' 'dini' 'dini' 'dini' 'imani' 'dini' 'dini' 'dini']	['enye dakizo']	['teknolojia' 'ufundi' 'teknolojia' 'ufundi' 'teknolojia' 'teknolojia'
#  'ufundi' 'teknolojia' 'tekinolojia' 'teknolojia' 'tekinolojia'
#  'teknolojia' 'tekinolojia' 'teknologia']
# []	['ukonwaba']	[]	[]	['inkolo']	[]	[]
# ['iṣẹ́ òwò' 'ẹjọ́ tó kan ni' 'òwò' 'òwò']	['eréàsè àpèjẹìdálárayáìfisọkàn' 'ìdálárayá' 'aré']	['ìleradídá ara' 'ìleradídá ara' 'ajẹmọ́lera' 'ajẹmọ́-ìlera' 'àìkú'
#  '?gbogbo-arále']	['oyé ìṣìṣé àkóso ìlú' 'ìṣèlú' 'ọgbọ́n ìṣèlú' 'ọ̀ràn ílú' 'ìṣèlú' 'ìṣèlú']	['ìsìn ẹ̀sìn' 'ìsìn' 'è̩sìn']	['eré-ìdárayá' 'eré ìdárayá']	['ṣe ìfàgùn ìgbésí ayé ènìà' 'tẹkinọ́lọ́jì']

# %%
for lang in sa_langs:
    for label in sa_labels:
        bdf = bdfs[lang]
        print(lang, label, bdf.loc[bdf['eng'] == label, lang].values)
# Out:
# aym entailment []
# aym neutral []
# aym contradiction []
# bzd entailment []
# bzd neutral []
# bzd contradiction []
# cni entailment []
# cni neutral []
# cni contradiction []
# grn entailment []
# grn neutral []
# grn contradiction []
# hch entailment []
# hch neutral []
# hch contradiction []
# nah entailment []
# nah neutral []
# nah contradiction []
# oto entailment []
# oto neutral []
# oto contradiction []
# quy entailment []
# quy neutral []
# quy contradiction ['ayñi' 'hayu']
# shp entailment []
# shp neutral []
# shp contradiction []
# tar entailment []
# tar neutral []
# tar contradiction []

# %%
for lang in id_langs:
    for label in id_labels:
        bdf = bdfs[lang]
        print(lang, label, bdf.loc[bdf['eng'] == label, lang].values)
# Out:
# bbc negative []
# bbc neutral []
# bbc positive []
# sun negative []
# sun neutral []
# sun positive []
# jav negative []
# jav neutral []
# jav positive []
# mad negative []
# mad neutral []
# mad positive []
# mak negative []
# mak neutral []
# mak positive []
# min negative []
# min neutral []
# min positive []

# %%
for lang in tsm_langs:
    for label in tsm_labels:
        bdf = bdfs[lang]
        print(lang, label, bdf.loc[bdf['eng'] == label, lang].values)
# Out:
# ara negative []
# ara neutral []
# ara positive []
# fra negative ['négatif' 'négatif' 'cliché' 'épreuve négative' 'négatif' 'négatif'
#  'négatif' 'négatif' 'négatif' 'négation' 'démenti' 'négatif' 'négatif'
#  'négatif' 'négatif' 'négation' 'nier' 'réfuter' 'rejeter' 'repousser'
#  'négatif' 'négatif' 'négatif' 'négatif' 'négatif' 'négatif' 'négatif'
#  'négatif' 'négatif' 'négatif' 'négatif' 'négatif' 'négatif' 'négatif'
#  'négatif' 'négatif' 'non' 'négatif' 'électronégatif' 'négatif' 'négatif'
#  'négatif' 'apophatique' 'négatif' 'négatif' 'strictement négatif'
#  'négatif' 'strictement négatif' 'négatif' 'strictement négatif' 'négatif'
#  'strictement négatif' 'négatif' 'strictement négatif' 'négatif'
#  'strictement négatif' 'négatif' 'strictement négatif' 'négatif'
#  'strictement négatif' 'négatif' 'strictement négatif' 'négatif'
#  'strictement négatif' 'strictement négatif' 'négatif' 'négatif' 'négatif'
#  'film négatif' 'négatif' 'négatif' 'négatif' 'négatif'
#  'strictement négatif' 'négatif' 'négatif' 'négatif' 'glacé' 'ennemi'
#  'hostile' 'négatif' 'négatif' 'négatif' 'négatif' 'négatif' 'négatif'
#  'négatif' 'négatif' 'faire la sourde oreille' 'rejeter' 'non' 'négatif']
# fra neutral ['neutre' 'neutre' 'neutre' 'indifférent' 'neutre' 'neutre' 'neutre'
#  'neutre' 'neutre' 'neutre' 'neutre' 'neutre' 'neutre' 'neutre' 'neutre'
#  'achromatique' 'neutre' 'impersonnel' 'neutre' 'neutre' 'indifférent'
#  'neutre' 'neutre' 'point mort' 'neutre' 'neutre' 'neutre' 'neutre'
#  'neutre' 'neutre' 'neutraliste' 'neutre' 'neutre' 'point mort' 'neutre'
#  'neutre']
# fra positive ['définitif' 'positif' 'positif' 'positive' 'positif' 'formel' 'certain'
#  'sûr' 'positif' 'affirmation' 'positif' 'actif' 'dynamique'
#  'entreprenant' 'positif' 'énergiquement' 'positivement'
#  'constructivement' 'positif' 'positif' 'positif' 'affirmatif' 'positif'
#  'positif' 'positif' 'électropositif' 'positif' 'positif' 'excédentaire'
#  'positif' 'positif' 'affirmatif' 'plus' 'positif' 'strictement positif'
#  'convaincu' 'positif' 'strictement positif' 'positif'
#  'strictement positif' 'irréfutable' 'positif' 'strictement positif'
#  'positif' 'strictement positif' 'positif' 'strictement positif' 'positif'
#  'strictement positif' 'positif' 'strictement positif' 'positif'
#  'strictement positif' 'positif' 'strictement positif' 'positif' 'positif'
#  'positif' 'strictement positif' 'desmodromique' 'positif' 'positif'
#  'strictement positif' 'positif' 'positif' 'indéniable' 'positif'
#  'positif' 'positif' 'certain' 'positif' 'positive' 'positif']
# deu negative ['negativ' 'Negativ' 'Negativ' 'negativ' 'ablehnend' 'ohne Befund'
#  'negativ' 'Negativ' 'negativ' 'Negativ' 'Negativbild' 'Negativität'
#  'Negativ' 'negativer Pol' 'ablehnend' 'negativ' 'verneinend' 'negativ'
#  'negative Zahl' 'Negation' 'Verneinung' 'Dementi' 'Ableugnung'
#  'Negativbild' 'Trockenplatte' 'fotografische Platte' 'negativ'
#  'ablehnend' 'negativ' 'Negative' 'negativ' 'negativ' 'negativ' 'falsch'
#  'negativ' 'negativ' 'nein' 'negative' 'negative' 'Negativ' 'negativ'
#  'Negativ' 'negativ' 'schlecht' 'negativ' 'negativ' 'Negativ'
#  'Negativfilm' 'Negativ' 'negativ' 'negativ' 'negativ' 'negativ'
#  'Verneinung' 'negativ' 'negativ' 'negativ' 'nachteilig' 'ungünstig'
#  'pessimistisch' 'negativ' 'negativ' 'negativ' 'Negativfilm' 'verneinend'
#  'negativ' 'negativ' 'ablehnend' 'abschlägig' 'negativ' 'Negativ'
#  'verneinend' 'abbürsten' 'ablehnen' 'abweisen' 'beiseite schieben'
#  'nicht beachten' 'zurückweisen' 'überhaupt nicht berücksichtigen' 'Nein']
# deu neutral ['neutral' 'nullleiter' 'neutral' 'neutral' 'unparteiisch' 'unparteilich'
#  'Nulleiter' 'Leerlauf' 'neutrale Haltung' 'Nulleiter' 'neutral' 'Null…'
#  'Nullleiter' 'Ruhe…' 'neutral' 'neutral' 'neutral' 'Neutraler' 'Ruhelage'
#  'Leerlaufstellung' 'neutral' 'neutral' 'neutral' 'neutral' 'neutral'
#  'nulleiter' 'neutral' 'neutral' 'neutral' 'neutral' 'Leerlauf' 'neutral'
#  'parteilos' 'ungeladen']
# deu positive ['definitiv' 'endgültig' 'entscheidend' 'unwiderruflich' 'abschliessend'
#  'positiv' 'positiv' 'fasslich' 'konkret' 'wirklich' 'positiv' 'positiv'
#  'Positiv' 'positiv' 'Affirmation' 'Bejahung' 'Bestätigung' 'Zustimmung'
#  'empirisch' 'Positivität' 'energisch' 'aktiv' 'positiv' 'Vorausschauen'
#  'Nach-Vorne-Gewandt-Sein' 'bestimmt' 'definitiv' 'entschieden' 'sicher'
#  'zuverlässig' 'positiv' 'positiv' 'offensichtlich' 'wahr' 'positiv'
#  'positiv' 'Positiv' 'Positiv' 'positiv' 'bejahend' 'Positiv' 'Positiv'
#  'Positivfilm' 'Positiv' 'Grundstufe' 'Positivus' 'positiv' 'Positiv'
#  'Grundstufe' 'positiv' 'positiv' 'Positiv' 'unumstößlich' 'positiv'
#  'positiv' 'positiv' 'gewiss' 'zweifellos' 'sicher' 'unzweifelhaft'
#  'positiv' 'Grundstufe' 'Positiv' 'eindeutig' 'positiv' 'Positiv' 'sicher']
# hin negative ['नकारात्मक' 'नकार' 'निगेटिवफोटोका' 'नहीं हैं' 'नकारात्मक'
#  'अस्वीकार सूचक शब्द वा वर्णन' 'अस्वीकार सूचक' 'इंकारी' 'ऋण' 'ऋणात्मक'
#  'निषेधात्मक' 'अभाव सूचक' 'अस्वीकार करना' 'विरोध करना' 'प्रतिकार करना'
#  'निष्फल करना' 'निषेधात्मक' 'प्रतिकूल' 'रृणात्मक' 'निगेटिव'
#  'मानने से इन्कार करना' 'नकारात्मक' 'रृणात्मक' 'नकार' 'ऋणात्मक' 'नकार'
#  'नकारात्मक']
# hin neutral ['तटस्थ' 'निष्पक्ष' 'तटस्थ' 'मध्यस्थ' 'न इस ओर का न उस ओर का'
#  'बीच की राह का' 'न अच्छा न बुरा' 'उदासीन' 'बेसरोकार' 'अपक्षपाती'
#  'निष्पक्ष' 'वह जो किसी ओर भाग न ले' 'अपक्षपाती व्यक्ति या जाति' 'बलशून्य'
#  'तटस्थ' 'तटस्थ राष्ट्र' 'तटस्थ' 'किन्नर' 'बलशून्य']
# hin positive ['सकारात्मक' 'निश्चयात्मक' 'पक्का' 'प्रभावयुक्त' 'सुनिश्चित' 'धनात्मक'
#  'स्थिर' 'सुनिश्चित' 'निश्चय' 'निस्सन्देह' 'पक्का' 'धनात्मक' 'निर्णायक'
#  'वास्तविक' 'प्रत्यक्षवादी' 'धनात्मक' 'सकारात्मक' 'स्पष्ट' 'पूर्ण'
#  'निश्चित' 'सकारात्मक' 'धन' 'आशावादी' 'फोटो' 'धनात्मक' 'सत्य' 'धनात्मक'
#  'सत्य' 'धनात्मक' 'सकारात्मक' 'सुनिश्चित']
# ita negative ['negativa' 'negativo' 'negativa' 'negativo' 'negativa' 'negativo'
#  'negativa' 'negativa' 'negativo' 'negativa' 'negativo' 'lastra'
#  'contrario' 'negazione' 'negativo' 'negativa' 'negazione' 'negativo'
#  'negativo' 'negativo' 'negativa' 'negativo' 'negazione' 'respingere'
#  'negativo' 'negativo' 'negativo' 'falso' 'negativo' 'negativo' 'no'
#  'negativa' 'negativa' 'negativo' 'negativo' 'negativa' 'negativo'
#  'negativo' 'negativo' 'negativa' 'negativo' 'negativa' 'negativo'
#  'negativa' 'negativo' 'negativo' 'negativo' 'negativo' 'negativo'
#  'ostile' 'malevolo' 'negazione' 'negativo' 'negativo' 'negativo'
#  'negativo' 'negativa' 'negativo' 'negativo' 'negativa' 'negativo'
#  'negativa' 'negativo' 'disattendere']
# ita neutral ['neutrale' 'neutrale' 'folle' 'neutrale' 'neutro' 'posizione di folle'
#  'neutro' 'neutrale' 'neutrale' 'neutrale' 'neutro' 'neutrale' 'neutro'
#  'neutrale' 'neutrale' 'neutrale' 'neutro' 'neutrale' 'neutro'
#  'indifferente' 'neutrale' 'neutrale' 'neutrale' 'neutrale' 'neutrale'
#  'neutro']
# ita positive ['definitivo' 'positivo' 'preciso' 'positivo' 'positivo' 'preciso'
#  'definitivo' 'positivo' 'positivo' 'positivo' 'certo' 'evidente'
#  'positivo' 'vero' 'verace' 'positiva' 'positivo' 'convinto' 'positivo'
#  'positivistico' 'positivo' 'positivo' 'positivo' 'positiva' 'sicuro'
#  'positivo' 'positivo' 'positivo' 'positivo' 'positivo' 'sicuro' 'certo']
# por negative ['negativo' 'negativo' 'negativo' 'negativa' 'negativo' 'negativo' 'não'
#  'negativo' 'negativo' 'negativo' 'negativo' 'eletronegativo' 'negativo'
#  'negativo' 'negativo' 'vetar' 'negação' 'negativo' 'negativo' 'negativo'
#  'negativo' 'negativo' 'negativo' 'negativa' 'negativo' 'negativo'
#  'negação' 'negativo' 'negativo' 'negativo' 'negativo' 'negativo'
#  'negativo' 'negativo' 'negativo' 'negativo' 'negativo' 'não' 'negativo']
# por neutral ['neutro' 'neutro' 'neutral' 'neutro' 'neutro' 'neutra' 'neutra'
#  'acromático' 'neutral' 'neutro' 'impessoal' 'neutral' 'neutro' 'neutro'
#  'ponto morto' 'neutro' 'neutro' 'neutro' 'neutro' 'neutro' 'neutro'
#  'neutro' 'neutral' 'neutro' 'neutro']
# por positive ['decisivo' 'definitivo' 'positivo' 'real' 'positivo' 'real' 'positivo'
#  'certo' 'positivo' 'positiva' 'favorável' 'convencido' 'positiva'
#  'positiva' 'positivo' 'presunçoso' 'incontestável' 'irrefutável'
#  'positivo' 'vantajoso' 'positivo' 'positivo' 'positivo' 'positivo'
#  'positivo' 'positivo' 'positivo' 'positivo' 'positivo' 'positivo'
#  'positivo']
# spa negative ['negativo' 'negativo' 'negativo' 'negativo' 'negativa' 'negación'
#  'negativa' 'adverso' 'negativo' 'no' 'negativo' 'negativo'
#  'molde negativo' 'negativo' 'contrarrestar' 'desaprobar' 'desmentir'
#  'negación' 'negar' 'negativa' 'negativo' 'rechazar' 'negativo' 'negativo'
#  'negativo' 'falso' 'negativo' 'negativo' 'negativo' 'no'
#  'electronegativo' 'devastador' 'negativo' 'negativo' 'negativo'
#  'negativo' 'negativo' 'negativo' 'negativo' 'negativo' 'echar bola negra'
#  'negar' 'vetar' 'negativa' 'negativo' 'negativo' 'negativo' 'negativo'
#  'negativo' 'negativo' 'negativo' 'negativo' 'negativo' 'negativo'
#  'hostil' 'desmentido' 'negativo' 'negativo' 'negativo' 'negativo'
#  'negativo' 'negativo' 'negativo' 'negativo' 'no' 'negativo' 'desasistir'
#  'no' 'negativo']
# spa neutral ['neutral' 'neutral' 'neutro' 'punto muerto' 'punto neutro' 'neutral'
#  'neutro' 'neutral' 'neutro' 'impersonal' 'indiferente' 'neutral'
#  'neutral' 'neutro' 'neutro' 'indiferente' 'punto neutral' 'punto muerto'
#  'neutro' 'neutral' 'neutro' 'neutro' 'neutral' 'neutral']
# spa positive ['definitivo' 'positivo' 'positivo' 'afirmativo' 'enfático' 'categórico'
#  'positivo' 'positivo' 'molde positivo' 'afirmativo' 'definido' 'firme'
#  'indudable' 'positiva' 'positivo' 'preciso' 'seguro' 'cierto' 'evidente'
#  'positivo' 'veraz' 'verdadero' 'positivo' 'electropositivo' 'petulante'
#  'innegable' 'positiva' 'positivo' 'positivo' 'altivo' 'indudable'
#  'innegable' 'definitivo' 'positivo' 'útil' 'positiva' 'positivista'
#  'positivo' 'supuesto' 'positivo' 'positivo' 'positivo' 'grado positivo'
#  'positivo' 'positivo' 'positivo' 'provechoso' 'favorable' 'propicio'
#  'positivo' 'definitivo' 'concluyente' 'positivo' 'positivo' 'afirmativo'
#  'positivo']
